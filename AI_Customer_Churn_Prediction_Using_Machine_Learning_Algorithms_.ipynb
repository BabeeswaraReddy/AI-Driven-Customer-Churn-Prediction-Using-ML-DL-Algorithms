# %% [markdown]
# <a href="https://colab.research.google.com/github/BabeeswaraReddy/AI-Driven-Customer-Churn-Prediction-Using-ML-DL-Algorithms/blob/main/AI_Customer_Churn_Prediction_Using_Machine_Learning_Algorithms_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# Importing dataset
df = pd.read_csv('customer_churn.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
# Get the column names
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# Extract the 5th column & store it in ‘customer_5’
customer_5 = df[4:5]
customer_5
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#   MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 4            No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 4          No          No              No  Month-to-month              Yes
#
#       PaymentMethod MonthlyCharges  TotalCharges Churn
# 4  Electronic check           70.7        151.65   Yes
#
# [1 rows x 21 columns]

# %%
# Extract the 15th column & store it in ‘customer_15’
customer_15 = df[15:16]
customer_15
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 15  3655-SNQYZ  Female              0     Yes        Yes      69          Yes
#
#    MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 15           Yes     Fiber optic            Yes  ...              Yes
#
#    TechSupport StreamingTV StreamingMovies  Contract PaperlessBilling  \
# 15         Yes         Yes             Yes  Two year               No
#
#               PaymentMethod MonthlyCharges  TotalCharges Churn
# 15  Credit card (automatic)         113.25       7895.15    No
#
# [1 rows x 21 columns]

# %%
# Extract all the male senior citizens whose Payment Method is Electronic check & store the result in ‘senior_male_electronic’
senior_male_electronic = df[(df['gender'] == 'Male') & (df['SeniorCitizen'] == 1) & (df['PaymentMethod'] == 'Electronic check')]
senior_male_electronic
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 20    8779-QRDMV   Male              1      No         No       1
# 55    1658-BYGOY   Male              1      No         No      18
# 57    5067-XJQFU   Male              1     Yes        Yes      66
# 78    0191-ZHSKZ   Male              1      No         No      30
# 91    2424-WVHPL   Male              1      No         No       1
# ...          ...    ...            ...     ...        ...     ...
# 6837  6229-LSCKB   Male              1      No         No       6
# 6894  1400-MMYXY   Male              1     Yes         No       3
# 6914  7142-HVGBG   Male              1     Yes         No      43
# 6967  8739-WWKDU   Male              1      No         No      25
# 7032  6894-LFHLY   Male              1      No         No       1
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 20             No  No phone service             DSL             No  ...
# 55            Yes               Yes     Fiber optic             No  ...
# 57            Yes               Yes     Fiber optic             No  ...
# 78            Yes                No             DSL            Yes  ...
# 91            Yes                No     Fiber optic             No  ...
# ...           ...               ...             ...            ...  ...
# 6837          Yes                No     Fiber optic             No  ...
# 6894          Yes               Yes     Fiber optic             No  ...
# 6914          Yes               Yes     Fiber optic             No  ...
# 6967          Yes               Yes     Fiber optic             No  ...
# 7032          Yes               Yes     Fiber optic             No  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 20                Yes          No          No             Yes  Month-to-month
# 55                 No          No         Yes             Yes  Month-to-month
# 57                Yes         Yes         Yes             Yes        One year
# 78                 No          No         Yes             Yes  Month-to-month
# 91                 No         Yes          No              No  Month-to-month
# ...               ...         ...         ...             ...             ...
# 6837               No          No         Yes              No  Month-to-month
# 6894              Yes          No         Yes             Yes  Month-to-month
# 6914              Yes          No         Yes             Yes  Month-to-month
# 6967               No          No         Yes              No  Month-to-month
# 7032               No          No          No              No  Month-to-month
#
#      PaperlessBilling     PaymentMethod MonthlyCharges  TotalCharges Churn
# 20                Yes  Electronic check          39.65         39.65   Yes
# 55                Yes  Electronic check          95.45       1752.55   Yes
# 57                Yes  Electronic check         108.45       7076.35    No
# 78                Yes  Electronic check          74.75        2111.3    No
# 91                 No  Electronic check          74.70          74.7    No
# ...               ...               ...            ...           ...   ...
# 6837              Yes  Electronic check          79.70         497.6    No
# 6894              Yes  Electronic check         105.90        334.65   Yes
# 6914              Yes  Electronic check         103.00        4414.3   Yes
# 6967              Yes  Electronic check          89.50       2196.15   Yes
# 7032              Yes  Electronic check          75.75         75.75   Yes
#
# [298 rows x 21 columns]

# %%
# Extract all those customers whose tenure is greater than 70 months or their Monthly charges is more than 100$ & store the result in ‘customer_total_tenure’
customer_total_tenure = df[(df['tenure'] > 70) | (df['MonthlyCharges'] > 100)]
customer_total_tenure
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 8     7892-POOKP  Female              0     Yes         No      28
# 12    8091-TTVAX    Male              0     Yes         No      58
# 13    0280-XJGEX    Male              0      No         No      49
# 14    5129-JLPIS    Male              0      No         No      25
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# ...          ...     ...            ...     ...        ...     ...
# 7023  1035-IPQPU  Female              1     Yes         No      63
# 7034  0639-TSIQW  Female              0      No         No      67
# 7037  2569-WGERO  Female              0      No         No      72
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 8             Yes           Yes     Fiber optic                   No  ...
# 12            Yes           Yes     Fiber optic                   No  ...
# 13            Yes           Yes     Fiber optic                   No  ...
# 14            Yes            No     Fiber optic                  Yes  ...
# 15            Yes           Yes     Fiber optic                  Yes  ...
# ...           ...           ...             ...                  ...  ...
# 7023          Yes           Yes     Fiber optic                   No  ...
# 7034          Yes           Yes     Fiber optic                  Yes  ...
# 7037          Yes            No              No  No internet service  ...
# 7039          Yes           Yes     Fiber optic                   No  ...
# 7042          Yes            No     Fiber optic                  Yes  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 8                     Yes                  Yes                  Yes
# 12                    Yes                   No                  Yes
# 13                    Yes                   No                  Yes
# 14                    Yes                  Yes                  Yes
# 15                    Yes                  Yes                  Yes
# ...                   ...                  ...                  ...
# 7023                  Yes                   No                  Yes
# 7034                  Yes                   No                  Yes
# 7037  No internet service  No internet service  No internet service
# 7039                  Yes                   No                  Yes
# 7042                  Yes                  Yes                  Yes
#
#           StreamingMovies        Contract PaperlessBilling  \
# 8                     Yes  Month-to-month              Yes
# 12                    Yes        One year               No
# 13                    Yes  Month-to-month              Yes
# 14                    Yes  Month-to-month              Yes
# 15                    Yes        Two year               No
# ...                   ...             ...              ...
# 7023                  Yes  Month-to-month              Yes
# 7034                   No  Month-to-month              Yes
# 7037  No internet service        Two year              Yes
# 7039                  Yes        One year              Yes
# 7042                  Yes        Two year              Yes
#
#                   PaymentMethod MonthlyCharges  TotalCharges Churn
# 8              Electronic check         104.80       3046.05   Yes
# 12      Credit card (automatic)         100.35        5681.1    No
# 13    Bank transfer (automatic)         103.70        5036.3   Yes
# 14             Electronic check         105.50       2686.05    No
# 15      Credit card (automatic)         113.25       7895.15    No
# ...                         ...            ...           ...   ...
# 7023           Electronic check         103.50        6479.4    No
# 7034    Credit card (automatic)         102.95       6886.25   Yes
# 7037  Bank transfer (automatic)          21.15        1419.4    No
# 7039    Credit card (automatic)         103.20        7362.9    No
# 7042  Bank transfer (automatic)         105.65        6844.5    No
#
# [1259 rows x 21 columns]

# %%
#Extract all the customers whose Contract is of two years, payment method is Mailed
# check & the value of Churn is ‘Yes’ & store the result in ‘two_mail_yes’
two_mail_yes = df[(df['Contract'] == 'Two year') & (df['PaymentMethod'] == 'Mailed check') & (df['Churn'] == 'Yes')]
two_mail_yes
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 268   6323-AYBRX    Male              0      No         No      59
# 5947  7951-QKZPL  Female              0     Yes        Yes      33
# 6680  9412-ARGBX  Female              0      No        Yes      48
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 268           Yes            No              No  No internet service  ...
# 5947          Yes           Yes              No  No internet service  ...
# 6680          Yes            No     Fiber optic                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 268   No internet service  No internet service  No internet service
# 5947  No internet service  No internet service  No internet service
# 6680                  Yes                  Yes                  Yes
#
#           StreamingMovies  Contract PaperlessBilling PaymentMethod  \
# 268   No internet service  Two year               No  Mailed check
# 5947  No internet service  Two year              Yes  Mailed check
# 6680                   No  Two year              Yes  Mailed check
#
#      MonthlyCharges  TotalCharges Churn
# 268           19.35        1099.6   Yes
# 5947          24.50         740.3   Yes
# 6680          95.50       4627.85   Yes
#
# [3 rows x 21 columns]

# %%
# Extract 333 random records from the customer_churndataframe& store the result in ‘customer_333’
customer_333 = df.sample(n=333, random_state=42)
customer_333
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 185   1024-GUALD  Female              0     Yes         No       1
# 2715  0484-JPBRU    Male              0      No         No      41
# 3825  3620-EHIMZ  Female              0     Yes        Yes      52
# 1807  6910-HADCM  Female              0      No         No       1
# 132   8587-XYZSF    Male              0      No         No      67
# ...          ...     ...            ...     ...        ...     ...
# 1451  6890-PFRQX    Male              0      No         No      18
# 3601  1552-CZCLL  Female              0     Yes        Yes      55
# 2149  2014-MKGMH  Female              0      No         No      46
# 5141  0303-WMMRN    Male              0      No         No       5
# 2087  3806-DXQOM  Female              0      No         No       4
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 185            No  No phone service             DSL                   No  ...
# 2715          Yes               Yes              No  No internet service  ...
# 3825          Yes                No              No  No internet service  ...
# 1807          Yes                No     Fiber optic                   No  ...
# 132           Yes                No             DSL                   No  ...
# ...           ...               ...             ...                  ...  ...
# 1451          Yes               Yes             DSL                  Yes  ...
# 3601          Yes                No              No  No internet service  ...
# 2149          Yes               Yes     Fiber optic                   No  ...
# 5141          Yes                No              No  No internet service  ...
# 2087           No  No phone service             DSL                  Yes  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 185                    No                   No                   No
# 2715  No internet service  No internet service  No internet service
# 3825  No internet service  No internet service  No internet service
# 1807                  Yes                   No                   No
# 132                    No                  Yes                   No
# ...                   ...                  ...                  ...
# 1451                  Yes                   No                  Yes
# 3601  No internet service  No internet service  No internet service
# 2149                  Yes                   No                  Yes
# 5141  No internet service  No internet service  No internet service
# 2087                   No                   No                   No
#
#           StreamingMovies        Contract PaperlessBilling  \
# 185                    No  Month-to-month              Yes
# 2715  No internet service  Month-to-month              Yes
# 3825  No internet service        Two year               No
# 1807                   No  Month-to-month               No
# 132                    No        Two year               No
# ...                   ...             ...              ...
# 1451                   No  Month-to-month               No
# 3601  No internet service  Month-to-month               No
# 2149                  Yes        One year              Yes
# 5141  No internet service  Month-to-month              Yes
# 2087                   No  Month-to-month              Yes
#
#                   PaymentMethod MonthlyCharges  TotalCharges Churn
# 185            Electronic check          24.80          24.8   Yes
# 2715  Bank transfer (automatic)          25.25        996.45    No
# 3825               Mailed check          19.35        1031.7    No
# 1807           Electronic check          76.35         76.35   Yes
# 132   Bank transfer (automatic)          50.55        3260.1    No
# ...                         ...            ...           ...   ...
# 1451               Mailed check          69.50        1199.4    No
# 3601    Credit card (automatic)          20.00       1087.25    No
# 2149           Electronic check         101.10        4674.4    No
# 5141               Mailed check          19.25         86.05    No
# 2087           Electronic check          33.65        137.85   Yes
#
# [333 rows x 21 columns]

# %%
# Get the count of different levels from the ‘Churn’ column
churn_counts = df['Churn'].value_counts()
churn_counts
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
# Count the occurrences of each category
service_counts = df['InternetService'].value_counts()

# Create the bar plot
plt.figure(figsize=(10, 6))
plt.bar(service_counts.index, service_counts.values, color='orange')

# Set the x-axis label
plt.xlabel('Categories of Internet Service')

# Set the y-axis label
plt.ylabel('Count of Categories')

# Set the title of the plot
plt.title('Distribution of Internet Service')

# Show the plot
plt.show()

# %%
# Create the histogram
df['tenure'].plot.hist(bins=30, color='green')

# Set the title of the plot
plt.title('Distribution of tenure')

# Display the plot
plt.show()

# %%
# Create the scatter plot
df.plot.scatter(x='tenure', y='MonthlyCharges', color='brown')

# Set the x-axis label
plt.xlabel('Tenure of customer')

# Set the y-axis label
plt.ylabel('Monthly Charges of customer')

# Set the title of the plot
plt.title('Tenure vs Monthly Charges')

# Display the plot
plt.show()

# %%
# Create the box plot
df.plot.box(x='Contract', y='tenure')

# Set the x-axis label
plt.xlabel('Contract')

# Set the y-axis label
plt.ylabel('Tenure')

# Set the title of the plot
plt.title('Tenure by Contract')

# Display the plot
plt.show()

# %%
from sklearn.model_selection import train_test_split

# Split the data into train and test sets (70:30 ratio)
X = df[['tenure']]
y = df['MonthlyCharges']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Train the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
print("Linear_Regression Mean Squared Error:", mse)

rmse = np.sqrt(mse)
print("Linear_Regression Root Mean Squared Error:", rmse)

error_in_linear_model = y_test - y_pred
# Out:
# Linear_Regression Mean Squared Error: 845.6091871095867
# Linear_Regression Root Mean Squared Error: 29.07936015646814

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score

# Split the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(df['MonthlyCharges'], df['Churn'], test_size=0.35, random_state=42)

# Reshape the features array as a 2D array
X_train = X_train.values.reshape(-1, 1)
X_test = X_test.values.reshape(-1, 1)

# Create and fit the logistic regression model
model = LogisticRegression()
model.fit(X_train, y_train)

# Predict the values on the test set
y_pred = model.predict(X_test)

# Build the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Get the accuracy score
logistic_regression_accuracy = accuracy_score(y_test, y_pred)

# Print the confusion matrix and accuracy score
print("Logistic Regression Confusion Matrix:")
print(conf_matrix)
print("Logistic Regression Accuracy Score:", logistic_regression_accuracy)
# Out:
# Logistic Regression Confusion Matrix:
# [[1797    0]
#  [ 669    0]]
# Logistic Regression Accuracy Score: 0.7287104622871047

# %%
# Building a multiple logistic regression model

# Split the dataset into train and test sets
X = df[['tenure', 'MonthlyCharges']]
y = df['Churn']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# Create and fit the logistic regression model
model = LogisticRegression()
model.fit(X_train, y_train)

# Predict the values on the test set
y_pred = model.predict(X_test)

# Build the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Get the accuracy score
multiple_logistic_regression_accuracy = accuracy_score(y_test, y_pred)

# Print the confusion matrix and accuracy score
print("Multiple Logistic Regression Confusion Matrix:")
print(conf_matrix)
print("Multiple Logistic Regression Accuracy Score:", multiple_logistic_regression_accuracy)
# Out:
# Multiple Logistic Regression Confusion Matrix:
# [[944  92]
#  [193 180]]
# Multiple Logistic Regression Accuracy Score: 0.7977288857345636

# %%
from sklearn.tree import DecisionTreeClassifier

# Split the dataset into train and test sets
X = df[['tenure']]
y = df['Churn']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# Create and fit the decision tree model
model = DecisionTreeClassifier()
model.fit(X_train, y_train)

# Predict the values on the test set
y_pred = model.predict(X_test)

# Build the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Calculate the accuracy score
decision_tree_accuracy = accuracy_score(y_test, y_pred)

# Print the confusion matrix and accuracy score
print("Decision Tree Confusion Matrix:\n",conf_matrix)
print("Decision Tree Accuracy Score:", decision_tree_accuracy)
# Out:
# Decision Tree Confusion Matrix:
#  [[951  85]
#  [257 116]]
# Decision Tree Accuracy Score: 0.7572746628814763

# %%
from sklearn.ensemble import RandomForestClassifier

# Split the dataset into train and test sets
X = df[['tenure', 'MonthlyCharges']]
y = df['Churn']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# Create and fit the decision tree model
model1 = RandomForestClassifier()
model1.fit(X_train, y_train)

# Predict the values on the test set
y_pred = model1.predict(X_test)

# Build the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Calculate the accuracy score
random_forest_accuracy = accuracy_score(y_test, y_pred)

# Print the confusion matrix and accuracy score
print("Random Forest Confusion Matrix:\n",conf_matrix)
print("Random Forest Accuracy Score:", random_forest_accuracy)
# Out:
# Random Forest Confusion Matrix:
#  [[887 149]
#  [197 176]]
# Random Forest Accuracy Score: 0.7544357700496807

# %%
# Data for the plot
models_accuracy = ["Logistic Regression", "Multiple Logistic Regression", "Decision Tree", "Random Forest"]
accuracy_scores = [logistic_regression_accuracy, multiple_logistic_regression_accuracy, decision_tree_accuracy, random_forest_accuracy]
rmse_score = rmse  # RMSE for Linear Regression

# Creating two subplots
fig, ax = plt.subplots(1, 2, figsize=(20, 6))

# Plotting RMSE in the first subplot
ax[0].bar(["Linear Regression (RMSE)"], [rmse_score], color='orange')
ax[0].set_title("Linear Regression RMSE")
ax[0].set_ylabel("RMSE Score")
for bar in ax[0].containers[0]:
    yval = bar.get_height()
    ax[0].text(bar.get_x() + bar.get_width() / 2, yval, round(yval, 2), ha='center', va='bottom')

# Plotting accuracy scores in the second subplot
bars = ax[1].bar(models_accuracy, accuracy_scores, color='blue')
ax[1].set_title("Model Accuracy Scores")
ax[1].set_ylabel("Accuracy (%)")
for bar in bars:
    yval = bar.get_height()
    ax[1].text(bar.get_x() + bar.get_width() / 2, yval, round(yval, 2), ha='center', va='bottom')

# Show the plot
plt.suptitle("Model Performance Comparison")
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
# Display all columns
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
# Filter the DataFrame to get Male customers
sum(df['gender'] == "Male")
# Out:
# 3555

# %%
# Filter the DataFrame to get DSL customers
sum(df['InternetService'] == 'DSL')
# Out:
# 2421

# %%
# Filter the DataFrame to get female customers who are senior citizens and use 'Mailed check' as their payment method
female_customer = df[
    (df['gender'] == 'Female') &                 # Condition: Gender should be Female
    (df['SeniorCitizen'] == 1) &                 # Condition: Senior Citizen indicator should be 1 (assumes 1 means True)
    (df['PaymentMethod'] == 'Mailed check')      # Condition: Payment method should be 'Mailed check'
]

# Display the first few rows of the resulting DataFrame
female_customer.head()
# Out:
#      customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 139  0390-DCFDQ  Female              1     Yes         No       1
# 176  2656-FMOKZ  Female              1      No         No      15
# 267  3197-ARFOY  Female              1      No         No      19
# 451  5760-WRAHC  Female              1      No         No      22
# 470  4933-IKULF  Female              1      No         No      17
#
#     PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 139          Yes            No     Fiber optic                   No  ...
# 176          Yes           Yes     Fiber optic                   No  ...
# 267          Yes            No     Fiber optic                  Yes  ...
# 451          Yes            No             DSL                  Yes  ...
# 470          Yes            No              No  No internet service  ...
#
#         DeviceProtection          TechSupport          StreamingTV  \
# 139                   No                   No                   No
# 176                   No                   No                   No
# 267                   No                  Yes                  Yes
# 451                  Yes                  Yes                   No
# 470  No internet service  No internet service  No internet service
#
#          StreamingMovies        Contract PaperlessBilling PaymentMethod  \
# 139                   No  Month-to-month              Yes  Mailed check
# 176                   No  Month-to-month              Yes  Mailed check
# 267                  Yes  Month-to-month              Yes  Mailed check
# 451                  Yes  Month-to-month              Yes  Mailed check
# 470  No internet service        One year               No  Mailed check
#
#     MonthlyCharges  TotalCharges Churn
# 139          70.45         70.45   Yes
# 176          74.45        1145.7   Yes
# 267         105.00       2007.25    No
# 451          69.75        1545.4    No
# 470          20.65         330.6    No
#
# [5 rows x 21 columns]

# %%
# Convert 'tenure' and 'TotalCharges' columns to numeric, forcing errors to NaN
df['tenure'] = pd.to_numeric(df['tenure'], errors='coerce')
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# Remove rows where 'tenure' or 'TotalCharges' is NaN
df = df.dropna(subset=['tenure', 'TotalCharges'])

# Now filter for new customers
new_customer = df[(df['tenure'] < 10) | (df['TotalCharges'] < 500)]
new_customer.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
# 7  6713-OKOMC  Female              0      No         No      10           No
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 2                No             DSL            Yes  ...               No
# 4                No     Fiber optic             No  ...               No
# 5               Yes     Fiber optic             No  ...              Yes
# 7  No phone service             DSL            Yes  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 2          No          No              No  Month-to-month              Yes
# 4          No          No              No  Month-to-month              Yes
# 5          No         Yes             Yes  Month-to-month              Yes
# 7          No          No              No  Month-to-month               No
#
#       PaymentMethod MonthlyCharges  TotalCharges  Churn
# 0  Electronic check          29.85         29.85     No
# 2      Mailed check          53.85        108.15    Yes
# 4  Electronic check          70.70        151.65    Yes
# 5  Electronic check          99.65        820.50    Yes
# 7      Mailed check          29.75        301.90     No
#
# [5 rows x 21 columns]

# %%
# Get the unique values from the 'Churn' column to use as labels for the pie chart
names = df["Churn"].value_counts().keys().tolist()

# Get the count of each unique value in the 'Churn' column to use as sizes for the pie chart
sizes = df["Churn"].value_counts().tolist()

# Create a pie chart using the sizes and labels, with percentage display for each slice
plt.pie(
    sizes,                   # Sizes of each pie section, based on count of 'Churn' values
    labels=names,            # Labels for each section (e.g., 'Yes' or 'No' if 'Churn' is binary)
    autopct='%1.1f%%'        # Display percentage with 1 decimal place
)

# Show the pie chart
plt.show()

# %%
# Create a bar plot for the counts of each category in the 'InternetService' column
plt.bar(
    df['InternetService'].value_counts().keys().tolist(),  # Get unique categories as x-axis labels
    df['InternetService'].value_counts().tolist(),         # Get the count of each category as y-axis values
    color='orange'                                         # Set the color of the bars to orange
)

# Label the x-axis as 'Categories of Internet Service'
plt.xlabel('Categories of Internet Service')

# Label the y-axis as 'Count of categories'
plt.ylabel('Count of categories')

# Set the title of the plot as 'Distribution of Internet Service'
plt.title('Distribution of Internet Service')

# Display the bar plot
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# Create a LabelEncoder object
le = LabelEncoder()

# Fit and transform the 'Churn' column
df['Churn'] = le.fit_transform(df['Churn'])

# Display the first few rows of the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7032 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     7032 non-null   int64
#  3   Partner           7032 non-null   object
#  4   Dependents        7032 non-null   object
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   object
#  7   MultipleLines     7032 non-null   object
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   object
#  10  OnlineBackup      7032 non-null   object
#  11  DeviceProtection  7032 non-null   object
#  12  TechSupport       7032 non-null   object
#  13  StreamingTV       7032 non-null   object
#  14  StreamingMovies   7032 non-null   object
#  15  Contract          7032 non-null   object
#  16  PaperlessBilling  7032 non-null   object
#  17  PaymentMethod     7032 non-null   object
#  18  MonthlyCharges    7032 non-null   float64
#  19  TotalCharges      7032 non-null   float64
#  20  Churn             7032 non-null   int64
# dtypes: float64(2), int64(3), object(16)
# memory usage: 1.2+ MB

# %%
# Select the 'tenure' column as the feature variable X
X = df[['tenure']]

# Select the 'Churn' column as the target variable Y
Y = df[['Churn']]

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(
    X, Y,                   # Features and target
    test_size=0.20,         # 20% of the data will be used for testing
    random_state=50         # Set a random state for reproducibility
)

# %%
# Import the Keras libraries and packages
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout

# Build the model
model = Sequential()
model.add(Dense(12, input_dim=1, activation='relu'))  # input_dim matches the feature count
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))  # sigmoid for binary classification

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=150, validation_data=(x_test, y_test))
# Out:
# Epoch 1/150
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7499 - loss: 0.5480 - val_accuracy: 0.7655 - val_loss: 0.4911
# Epoch 2/150
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7536 - loss: 0.5191 - val_accuracy: 0.7697 - val_loss: 0.4899
# Epoch 3/150
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7547 - loss: 0.5180 - val_accuracy: 0.7697 - val_loss: 0.4918
# Epoch 4/150
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7518 - loss: 0.5216 - val_accuracy: 0.7697 - val_loss: 0.4893
# Epoch 5/150
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7500 - loss: 0.5186 - val_accuracy: 0.7697 - val_loss: 0.4894
# Epoch 6/150
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7518 - loss: 0.5177 - val_accuracy: 0.7697 - val_loss: 0.4894
# Epoch 7/150
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7515 - loss: 0.5177 - val_accuracy: 0.7697 - val_loss: 0.4971
# Epoch 8/150
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7513 - loss: 0.5203 - val_accuracy: 0.7697 - val_loss: 0.4895
# Epoch 9/150
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7509 - loss: 0.5184 - val_accuracy: 0.7697 - val_loss: 0.4911
# Epoch 10/150
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7511 - loss: 0.5180 - val_accuracy: 0.7697 - val_loss: 0.4938
# Epoch 11/150
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7468 - loss: 0.5180 - val_accuracy: 0.7697 - val_loss: 0.4933
# Epoch 12/150
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7518 - loss: 0.5174 - val_accuracy: 0.7697 - val_loss: 0.4909
# Epoch 13/150
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7515 - loss: 0.5169 - val_accuracy: 0.7697 - val_loss: 0.5004
# Epoch 14/150
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7509 - loss: 0.5175 - val_accuracy: 0.7697 - val_loss: 0.4938
# Epoch 15/150
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7492 - loss: 0.5186 - val_accuracy: 0.7697 - val_loss: 0.4893
# Epoch 16/150
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7490 - loss: 0.5165 - val_accuracy: 0.7697 - val_loss: 0.4977
# Epoch 17/150
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7513 - loss: 0.5186 - val_accuracy: 0.7697 - val_loss: 0.4978
# Epoch 18/150
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7515 - loss: 0.5180 - val_accuracy: 0.7527 - val_loss: 0.4893
# Epoch 19/150
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7429 - loss: 0.5176 - val_accuracy: 0.7697 - val_loss: 0.4931
# Epoch 20/150
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.
150
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7518 - loss: 0.5117 - val_accuracy: 0.7655 - val_loss: 0.4877
# Epoch 147/150
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7540 - loss: 0.5117 - val_accuracy: 0.7655 - val_loss: 0.4896
# Epoch 148/150
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7540 - loss: 0.5121 - val_accuracy: 0.7655 - val_loss: 0.4901
# Epoch 149/150
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7531 - loss: 0.5116 - val_accuracy: 0.7655 - val_loss: 0.4886
# Epoch 150/150
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7531 - loss: 0.5120 - val_accuracy: 0.7655 - val_loss: 0.4886

# %%
# Display the keys of the training history
model.history.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
plt.plot(model.history.history['accuracy'], label='Training Accuracy')
plt.plot(model.history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
# Calculate the mean of the validation accuracy from the training history of the model
mean_val_accuracy = np.mean(model.history.history['val_accuracy'])

# Display the mean validation accuracy
mean_val_accuracy
# Out:
# np.float64(0.7646576571464538)

# %%
# Make predictions
y_pred_prob = model.predict(x_test)

# Convert probabilities to binary predictions using a threshold
threshold = 0.5
y_pred = (y_pred_prob > threshold).astype(int)  # Assuming binary classification

# Build the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Get the accuracy score
accuracy = accuracy_score(y_test, y_pred)

# Print the confusion matrix and accuracy score
print("Confusion Matrix:\n", conf_matrix)
print("Accuracy Score:", accuracy)
# Out:
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Confusion Matrix:
#  [[984  75]
#  [255  93]]
# Accuracy Score: 0.7654584221748401

# %%
# Sequential Model Building with dropout

# Initialize a sequential model
model = Sequential()

# Add the first dense layer with 12 units and ReLU activation
model.add(Dense(12, activation='relu'))

# Add a dropout layer with a dropout rate of 20% to prevent overfitting
model.add(Dropout(0.2))

# Add the second dense layer with 8 units and ReLU activation
model.add(Dense(8, activation='relu'))

# Add a dropout layer with a dropout rate of 10%
model.add(Dropout(0.1))

# Add the output layer with 1 unit and sigmoid activation for binary classification
model.add(Dense(1, activation='sigmoid'))

# Compile the model with binary cross-entropy loss, Adam optimizer, and accuracy as a metric
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model on the training data for 200 epochs, using validation data to evaluate performance
model.fit(x_train, y_train, epochs=200, validation_data=(x_test, y_test))
# Out:
# Epoch 1/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6396 - loss: 1.5011 - val_accuracy: 0.7527 - val_loss: 0.6473
# Epoch 2/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6871 - loss: 0.8965 - val_accuracy: 0.7655 - val_loss: 0.5125
# Epoch 3/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6862 - loss: 0.7260 - val_accuracy: 0.7576 - val_loss: 0.4911
# Epoch 4/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6955 - loss: 0.6377 - val_accuracy: 0.7697 - val_loss: 0.4983
# Epoch 5/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6786 - loss: 0.6025 - val_accuracy: 0.7527 - val_loss: 0.5075
# Epoch 6/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7022 - loss: 0.5833 - val_accuracy: 0.7527 - val_loss: 0.5007
# Epoch 7/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7129 - loss: 0.5499 - val_accuracy: 0.7527 - val_loss: 0.5138
# Epoch 8/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7198 - loss: 0.5453 - val_accuracy: 0.7527 - val_loss: 0.5260
# Epoch 9/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7223 - loss: 0.5416 - val_accuracy: 0.7527 - val_loss: 0.5103
# Epoch 10/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7214 - loss: 0.5425 - val_accuracy: 0.7527 - val_loss: 0.5003
# Epoch 11/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7255 - loss: 0.5371 - val_accuracy: 0.7527 - val_loss: 0.5097
# Epoch 12/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.
200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7294 - loss: 0.5250 - val_accuracy: 0.7527 - val_loss: 0.4960
# Epoch 46/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5262 - val_accuracy: 0.7527 - val_loss: 0.4961
# Epoch 47/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5260 - val_accuracy: 0.7527 - val_loss: 0.4971
# Epoch 48/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5271 - val_accuracy: 0.7527 - val_loss: 0.4980
# Epoch 49/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5269 - val_accuracy: 0.7527 - val_loss: 0.4997
# Epoch 50/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5249 - val_accuracy: 0.7527 - val_loss: 0.4984
# Epoch 51/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5227 - val_accuracy: 0.7527 - val_loss: 0.4959
# Epoch 52/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7296 - loss: 0.5231 - val_accuracy: 0.7527 - val_loss: 0.5008
# Epoch 53/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7296 - loss: 0.5233 - val_accuracy: 0.7527 - val_loss: 0.4991
# Epoch 54/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7296 - loss: 0.5265 - val_accuracy: 0.7527 - val_loss: 0.5025
# Epoch 55/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7294 - loss: 0.5271 - val_accuracy: 0.7527 - val_loss: 0.5004
# Epoch 56/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5253 - val_accuracy: 0.7527 - val_loss: 0.5013
# Epoch 57/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5277 - val_accuracy: 0.7527 - val_loss: 0.4934
# Epoch 58/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5258 - val_accuracy: 0.7527 - val_loss: 0.5002
# Epoch 59/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5263 - val_accuracy: 0.7527 - val_loss: 0.4957
# Epoch 60/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5237 - val_accuracy: 0.7527 - val_loss: 0.5051
# Epoch 61/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5252 - val_accuracy: 0.7527 - val_loss: 0.5001
# Epoch 62/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5226 - val_accuracy: 0.7527 - val_loss: 0.4959
# Epoch 63/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5235 - val_accuracy: 0.7527 - val_loss: 0.4954
# Epoch 64/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5246 - val_accuracy: 0.7527 - val_loss: 0.4954
# Epoch 65/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5237 - val_accuracy: 0.7527 - val_loss: 0.4961
# Epoch 66/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5258 - val_accuracy: 0.7527 - val_loss: 0.4958
# Epoch 67/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5261 - val_accuracy: 0.7527 - val_loss: 0.4961
# Epoch 68/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5240 - val_accuracy: 0.7527 - val_loss: 0.4968
# Epoch 69/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5234 - val_accuracy: 0.7527 - val_loss: 0.4973
# Epoch 70/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5251 - val_accuracy: 0.7527 - val_loss: 0.4992
# Epoch 71/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5248 - val_accuracy: 0.7527 - val_loss: 0.5016
# Epoch 72/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5231 - val_accuracy: 0.7527 - val_loss: 0.4918
# Epoch 73/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5258 - val_accuracy: 0.7527 - val_loss: 0.4987
# Epoch 74/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5244 - val_accuracy: 0.7527 - val_loss: 0.5032
# Epoch 75/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7296 - loss: 0.5253 - val_accuracy: 0.7527 - val_loss: 0.5061
# Epoch 76/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7296 - loss: 0.5249 - val_accuracy: 0.7527 - val_loss: 0.4992
# Epoch 77/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5249 - val_accuracy: 0.7527 - val_loss: 0.4970
# Epoch 78/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5218 - val_accuracy: 0.7527 - val_loss: 0.4954
# Epoch 79/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5273 - val_accuracy: 0.7527 - val_loss: 0.4936
# Epoch 80/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5269 - val_accuracy: 0.7527 - val_loss: 0.5013
# Epoch 81/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5222 - val_accuracy: 0.7527 - val_loss: 0.4934
# Epoch 82/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5251 - val_accuracy: 0.7527 - val_loss: 0.5026
# Epoch 83/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5260 - val_accuracy: 0.7527 - val_loss: 0.4981
# Epoch 84/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5242 - val_accuracy: 0.7527 - val_loss: 0.4995
# Epoch 85/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5246 - val_accuracy: 0.7527 - val_loss: 0.4925
# Epoch 86/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5252 - val_accuracy: 0.7527 - val_loss: 0.5004
# Epoch 87/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5214 - val_accuracy: 0.7527 - val_loss: 0.5040
# Epoch 88/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5249 - val_accuracy: 0.7527 - val_loss: 0.4993
# Epoch 89/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5239 - val_accuracy: 0.7527 - val_loss: 0.4969
# Epoch 90/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5248 - val_accuracy: 0.7527 - val_loss: 0.4986
# Epoch 91/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5260 - val_accuracy: 0.7527 - val_loss: 0.5000
# Epoch 92/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5250 - val_accuracy: 0.7527 - val_loss: 0.5002
# Epoch 93/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5252 - val_accuracy: 0.7527 - val_loss: 0.5032
# Epoch 94/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5258 - val_accuracy: 0.7527 - val_loss: 0.5049
# Epoch 95/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5228 - val_accuracy: 0.7527 - val_loss: 0.4968
# Epoch 96/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5253 - val_accuracy: 0.7527 - val_loss: 0.4997
# Epoch 97/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7296 - loss: 0.5233 - val_accuracy: 0.7527 - val_loss: 0.4952
# Epoch 98/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7296 - loss: 0.5242 - val_accuracy: 0.7527 - val_loss: 0.5015
# Epoch 99/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5267 - val_accuracy: 0.7527 - val_loss: 0.5016
# Epoch 100/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5244 - val_accuracy: 0.7527 - val_loss: 0.4959
# Epoch 101/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5245 - val_accuracy: 0.7527 - val_loss: 0.5034
# Epoch 102/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5263 - val_accuracy: 0.7527 - val_loss: 0.4994
# Epoch 103/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5233 - val_accuracy: 0.7527 - val_loss: 0.4937
# Epoch 104/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5256 - val_accuracy: 0.7527 - val_loss: 0.5005
# Epoch 105/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5265 - val_accuracy: 0.7527 - val_loss: 0.4973
# Epoch 106/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5218 - val_accuracy: 0.7527 - val_loss: 0.4981
# Epoch 107/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5226 - val_accuracy: 0.7527 - val_loss: 0.4926
# Epoch 108/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5233 - val_accuracy: 0.7527 - val_loss: 0.4990
# Epoch 109/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7296 - loss: 0.5253 - val_accuracy: 0.7527 - val_loss: 0.4996
# Epoch 110/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5225 - val_accuracy: 0.7527 - val_loss: 0.5034
# Epoch 111/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5248 - val_accuracy: 0.7527 - val_loss: 0.4935
# Epoch 112/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5233 - val_accuracy: 0.7527 - val_loss: 0.5019
# Epoch 113/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5231 - val_accuracy: 0.7527 - val_loss: 0.4983
# Epoch 114/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5259 - val_accuracy: 0.7527 - val_loss: 0.4945
# Epoch 115/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5255 - val_accuracy: 0.7527 - val_loss: 0.4988
# Epoch 116/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5245 - val_accuracy: 0.7527 - val_loss: 0.4960
# Epoch 117/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5237 - val_accuracy: 0.7527 - val_loss: 0.5088
# Epoch 118/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5247 - val_accuracy: 0.7527 - val_loss: 0.5007
# Epoch 119/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5262 - val_accuracy: 0.7527 - val_loss: 0.4977
# Epoch 120/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7296 - loss: 0.5244 - val_accuracy: 0.7527 - val_loss: 0.5011
# Epoch 121/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7296 - loss: 0.5233 - val_accuracy: 0.7527 - val_loss: 0.5015
# Epoch 122/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5230 - val_accuracy: 0.7527 - val_loss: 0.5047
# Epoch 123/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5245 - val_accuracy: 0.7527 - val_loss: 0.4998
# Epoch 124/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5251 - val_accuracy: 0.7527 - val_loss: 0.4984
# Epoch 125/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5241 - val_accuracy: 0.7527 - val_loss: 0.4982
# Epoch 126/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5253 - val_accuracy: 0.7527 - val_loss: 0.5013
# Epoch 127/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5230 - val_accuracy: 0.7527 - val_loss: 0.5023
# Epoch 128/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5227 - val_accuracy: 0.7527 - val_loss: 0.4951
# Epoch 129/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5245 - val_accuracy: 0.7527 - val_loss: 0.4932
# Epoch 130/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5242 - val_accuracy: 0.7527 - val_loss: 0.4992
# Epoch 131/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5238 - val_accuracy: 0.7527 - val_loss: 0.4980
# Epoch 132/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5238 - val_accuracy: 0.7527 - val_loss: 0.4935
# Epoch 133/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5206 - val_accuracy: 0.7527 - val_loss: 0.4925
# Epoch 134/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5238 - val_accuracy: 0.7527 - val_loss: 0.5002
# Epoch 135/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5244 - val_accuracy: 0.7527 - val_loss: 0.4936
# Epoch 136/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5240 - val_accuracy: 0.7527 - val_loss: 0.4949
# Epoch 137/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5237 - val_accuracy: 0.7527 - val_loss: 0.5003
# Epoch 138/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5262 - val_accuracy: 0.7527 - val_loss: 0.4957
# Epoch 139/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5216 - val_accuracy: 0.7527 - val_loss: 0.5085
# Epoch 140/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5239 - val_accuracy: 0.7527 - val_loss: 0.4926
# Epoch 141/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5249 - val_accuracy: 0.7527 - val_loss: 0.4954
# Epoch 142/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7296 - loss: 0.5235 - val_accuracy: 0.7527 - val_loss: 0.5020
# Epoch 143/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7296 - loss: 0.5234 - val_accuracy: 0.7527 - val_loss: 0.4978
# Epoch 144/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7296 - loss: 0.5260 - val_accuracy: 0.7527 - val_loss: 0.4981
# Epoch 145/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7296 - loss: 0.5261 - val_accuracy: 0.7527 - val_loss: 0.5003
# Epoch 146/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5269 - val_accuracy: 0.7527 - val_loss: 0.5066
# Epoch 147/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5243 - val_accuracy: 0.7527 - val_loss: 0.4989
# Epoch 148/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5253 - val_accuracy: 0.7527 - val_loss: 0.4961
# Epoch 149/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5272 - val_accuracy: 0.7527 - val_loss: 0.4991
# Epoch 150/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5252 - val_accuracy: 0.7527 - val_loss: 0.4984
# Epoch 151/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5236 - val_accuracy: 0.7527 - val_loss: 0.5004
# Epoch 152/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5246 - val_accuracy: 0.7527 - val_loss: 0.4943
# Epoch 153/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5254 - val_accuracy: 0.7527 - val_loss: 0.4980
# Epoch 154/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5239 - val_accuracy: 0.7527 - val_loss: 0.4993
# Epoch 155/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5249 - val_accuracy: 0.7527 - val_loss: 0.4961
# Epoch 156/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5233 - val_accuracy: 0.7527 - val_loss: 0.4987
# Epoch 157/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5204 - val_accuracy: 0.7527 - val_loss: 0.4935
# Epoch 158/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5244 - val_accuracy: 0.7527 - val_loss: 0.5031
# Epoch 159/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5228 - val_accuracy: 0.7527 - val_loss: 0.4966
# Epoch 160/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5247 - val_accuracy: 0.7527 - val_loss: 0.4944
# Epoch 161/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5271 - val_accuracy: 0.7527 - val_loss: 0.4956
# Epoch 162/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5256 - val_accuracy: 0.7527 - val_loss: 0.5009
# Epoch 163/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5224 - val_accuracy: 0.7527 - val_loss: 0.4953
# Epoch 164/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5252 - val_accuracy: 0.7527 - val_loss: 0.4988
# Epoch 165/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7296 - loss: 0.5232 - val_accuracy: 0.7527 - val_loss: 0.4987
# Epoch 166/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7296 - loss: 0.5231 - val_accuracy: 0.7527 - val_loss: 0.4965
# Epoch 167/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7296 - loss: 0.5256 - val_accuracy: 0.7527 - val_loss: 0.4954
# Epoch 168/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5246 - val_accuracy: 0.7527 - val_loss: 0.5002
# Epoch 169/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5247 - val_accuracy: 0.7527 - val_loss: 0.4962
# Epoch 170/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5250 - val_accuracy: 0.7527 - val_loss: 0.4924
# Epoch 171/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5237 - val_accuracy: 0.7527 - val_loss: 0.4955
# Epoch 172/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5266 - val_accuracy: 0.7527 - val_loss: 0.5035
# Epoch 173/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5232 - val_accuracy: 0.7527 - val_loss: 0.4973
# Epoch 174/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5263 - val_accuracy: 0.7527 - val_loss: 0.4966
# Epoch 175/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5253 - val_accuracy: 0.7527 - val_loss: 0.5004
# Epoch 176/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5236 - val_accuracy: 0.7527 - val_loss: 0.5033
# Epoch 177/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5268 - val_accuracy: 0.7527 - val_loss: 0.5034
# Epoch 178/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5251 - val_accuracy: 0.7527 - val_loss: 0.5004
# Epoch 179/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5216 - val_accuracy: 0.7527 - val_loss: 0.4981
# Epoch 180/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5248 - val_accuracy: 0.7527 - val_loss: 0.4968
# Epoch 181/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5219 - val_accuracy: 0.7527 - val_loss: 0.4961
# Epoch 182/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5237 - val_accuracy: 0.7527 - val_loss: 0.4988
# Epoch 183/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5243 - val_accuracy: 0.7527 - val_loss: 0.4922
# Epoch 184/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5254 - val_accuracy: 0.7527 - val_loss: 0.4992
# Epoch 185/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5228 - val_accuracy: 0.7527 - val_loss: 0.4979
# Epoch 186/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5263 - val_accuracy: 0.7527 - val_loss: 0.4999
# Epoch 187/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7296 - loss: 0.5251 - val_accuracy: 0.7527 - val_loss: 0.5038
# Epoch 188/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7296 - loss: 0.5223 - val_accuracy: 0.7527 - val_loss: 0.4903
# Epoch 189/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5259 - val_accuracy: 0.7527 - val_loss: 0.4971
# Epoch 190/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5242 - val_accuracy: 0.7527 - val_loss: 0.4980
# Epoch 191/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5272 - val_accuracy: 0.7527 - val_loss: 0.5025
# Epoch 192/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5248 - val_accuracy: 0.7527 - val_loss: 0.4977
# Epoch 193/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5236 - val_accuracy: 0.7527 - val_loss: 0.5033
# Epoch 194/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5237 - val_accuracy: 0.7527 - val_loss: 0.4965
# Epoch 195/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5234 - val_accuracy: 0.7527 - val_loss: 0.5038
# Epoch 196/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5222 - val_accuracy: 0.7527 - val_loss: 0.4944
# Epoch 197/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5212 - val_accuracy: 0.7527 - val_loss: 0.4968
# Epoch 198/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7296 - loss: 0.5268 - val_accuracy: 0.7527 - val_loss: 0.4941
# Epoch 199/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5226 - val_accuracy: 0.7527 - val_loss: 0.5024
# Epoch 200/200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7296 - loss: 0.5208 - val_accuracy: 0.7527 - val_loss: 0.4972

# %%
# Retrieve training accuracy from the model's history
model_train_accuracy = model.history.history['accuracy']

# Retrieve validation accuracy from the model's history
model_val_accuracy = model.history.history['val_accuracy']

# Plot the training accuracy
plt.plot(model_train_accuracy, label='Training Accuracy')

# Plot the validation accuracy
plt.plot(model_val_accuracy, label='Validation Accuracy')

# Set the title of the plot
plt.title('Model Accuracy')

# Label the y-axis
plt.ylabel('Accuracy')

# Label the x-axis
plt.xlabel('Epoch')

# Display a legend to differentiate between training and validation accuracy
plt.legend()

# Show the plot
plt.show()

# %%
# Generate predicted probabilities for the test set
y_pred_prob = model.predict(x_test)

# Define the threshold for classification
threshold = 0.5

# Convert predicted probabilities to binary predictions based on the threshold
y_pred = (y_pred_prob > threshold).astype(int)  # Assuming binary classification

# Build the confusion matrix to evaluate the model's performance
conf_matrix = confusion_matrix(y_test, y_pred)

# Calculate the accuracy score of the predictions
accuracy = accuracy_score(y_test, y_pred)

# Print the confusion matrix
print("Confusion Matrix:\n", conf_matrix)

# Print the accuracy score
print("Accuracy Score:", accuracy)
# Out:
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Confusion Matrix:
#  [[1059    0]
#  [ 348    0]]
# Accuracy Score: 0.7526652452025586

# %%
X =df[['MonthlyCharges','tenure','TotalCharges']] # Features
Y =df[['Churn']] # Target

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.30, random_state=42)

# %%
# Initialize the Sequential model
model = Sequential()

# Add the first hidden layer with 12 neurons, ReLU activation, and input shape defined
model.add(Dense(12, input_dim=3, activation='relu'))

# Add the second hidden layer with 8 neurons and ReLU activation
model.add(Dense(8, activation='relu'))

# Add the output layer with 1 neuron and sigmoid activation for binary classification
model.add(Dense(1, activation='sigmoid'))

# Compile the model with binary crossentropy loss, Adam optimizer, and accuracy metric
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model on the training data for 150 epochs
# Validation data is provided to monitor performance on unseen data
model.fit(X_train, y_train, epochs=250, validation_data=(X_test, y_test))
# Out:
# Epoch 1/250
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.5443 - loss: 1.9937 - val_accuracy: 0.5749 - val_loss: 1.3273
# Epoch 2/250
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5939 - loss: 1.0905 - val_accuracy: 0.7678 - val_loss: 0.8333
# Epoch 3/250
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7206 - loss: 0.8124 - val_accuracy: 0.4664 - val_loss: 0.9723
# Epoch 4/250
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7341 - loss: 0.8451 - val_accuracy: 0.7664 - val_loss: 0.5114
# Epoch 5/250
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7389 - loss: 0.8456 - val_accuracy: 0.7754 - val_loss: 0.7110
# Epoch 6/250
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7314 - loss: 0.8328 - val_accuracy: 0.7626 - val_loss: 0.4913
# Epoch 7/250
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7590 - loss: 0.5833 - val_accuracy: 0.7725 - val_loss: 0.7504
# Epoch 8/250
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7503 - loss: 0.7122 - val_accuracy: 0.7716 - val_loss: 0.5176
# Epoch 9/250
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7643 - loss: 0.5606 - val_accuracy: 0.6995 - val_loss: 0.5322
# Epoch 10/250
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7430 - loss: 0.8060 - val_accuracy: 0.7659 - val_loss: 0.5019
# Epoch 11/250
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7621 - loss: 0.6354 - val_accuracy: 0.5735 - val_loss: 0.7555
# Epoch 12/250
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7570 - loss: 0.6697 - val_accuracy: 0.7701 - val_loss: 1.7050
# Epoch 13/250
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7623 - loss: 0.5572 - val_accuracy: 0.7706 - val_loss: 0.4628
# Epoch 14/250
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.
250
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7891 - loss: 0.4519 - val_accuracy: 0.7791 - val_loss: 0.4667
# Epoch 235/250
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7905 - loss: 0.4580 - val_accuracy: 0.7810 - val_loss: 0.4690
# Epoch 236/250
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7901 - loss: 0.4579 - val_accuracy: 0.7839 - val_loss: 0.4641
# Epoch 237/250
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7865 - loss: 0.4548 - val_accuracy: 0.7844 - val_loss: 0.4591
# Epoch 238/250
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7859 - loss: 0.4542 - val_accuracy: 0.7754 - val_loss: 0.4623
# Epoch 239/250
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7881 - loss: 0.4531 - val_accuracy: 0.7825 - val_loss: 0.4705
# Epoch 240/250
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7883 - loss: 0.4571 - val_accuracy: 0.7820 - val_loss: 0.4685
# Epoch 241/250
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7903 - loss: 0.4555 - val_accuracy: 0.7706 - val_loss: 0.4709
# Epoch 242/250
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7903 - loss: 0.4516 - val_accuracy: 0.7829 - val_loss: 0.4583
# Epoch 243/250
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7875 - loss: 0.4535 - val_accuracy: 0.7782 - val_loss: 0.4724
# Epoch 244/250
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7887 - loss: 0.4551 - val_accuracy: 0.7872 - val_loss: 0.4603
# Epoch 245/250
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7873 - loss: 0.4580 - val_accuracy: 0.7735 - val_loss: 0.4650
# Epoch 246/250
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7875 - loss: 0.4581 - val_accuracy: 0.7773 - val_loss: 0.4718
# Epoch 247/250
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7901 - loss: 0.4558 - val_accuracy: 0.7848 - val_loss: 0.4713
# Epoch 248/250
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7891 - loss: 0.4549 - val_accuracy: 0.7787 - val_loss: 0.4682
# Epoch 249/250
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7924 - loss: 0.4552 - val_accuracy: 0.7427 - val_loss: 0.4964
# Epoch 250/250
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7901 - loss: 0.4540 - val_accuracy: 0.7787 - val_loss: 0.4643

# %%
print(np.mean(model.history.history['accuracy']))
print(np.mean(model.history.history['val_accuracy']))
# Out:
# 0.7701462812423706
# 0.7605687195062637

# %%
# Retrieve training accuracy from the model's history
model_train_accuracy = model.history.history['accuracy']

# Retrieve validation accuracy from the model's history
model_val_accuracy = model.history.history['val_accuracy']

# Plot the training accuracy
plt.plot(model_train_accuracy, label='Training Accuracy')

# Plot the validation accuracy
plt.plot(model_val_accuracy, label='Validation Accuracy')

# Set the title of the plot
plt.title('Model Accuracy')

# Label the y-axis
plt.ylabel('Accuracy')

# Label the x-axis
plt.xlabel('Epoch')

# Display a legend to differentiate between training and validation accuracy
plt.legend()

# Show the plot
plt.show()

# %%
# Model names and their corresponding accuracies
models = [
    "Keras Model 1 (without dropout)",
    "Keras Model 2 (with dropout)",
    "Keras Model 3 (multi-feature)"
]

accuracies = [76, 75, 77]  # Corresponding accuracies

# Choose different colors for the bars
colors = ['#4CAF50', '#2196F3', '#FF9800']  # Green, Blue, Orange

# Create a bar plot
plt.figure(figsize=(10, 6))
bars = plt.bar(models, accuracies, color=colors)

# Adding accuracy values on top of bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, f'{yval}%', ha='center', va='bottom')

# Adding labels and title
plt.ylabel('Accuracy (%)')
plt.title('Comparison of Keras Models for Customer Churn Prediction')
plt.ylim(0, 100)  # Set y-axis limit
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show plot
plt.tight_layout()
plt.show()
